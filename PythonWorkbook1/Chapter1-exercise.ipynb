# %% [markdown]
# Exercise 1

# %%
#Print("Hello World!")
print('Hello World!')
#The error in this line of code is the function printf the P is big
# Out:
# Hello World!

# %%
#print'Hello world!')
print('Hello world!')
#The error is the parenthesis
# Out:
# Hello world!

# %%
#print('Hello world!)
print ('Hello World!')
#The error is the missing single qoutation mark
# Out:
# Hello World!

# %%
#print('Hello world!'')
print('Hello world!')
#the error is the double quotation mark after the exclamation mark
# Out:
# Hello world!

# %% [markdown]
# Exercise 2

# %%
x = 43
x = x + 1
print(x)
#there is no error on this code
# Out:
# 44

# %% [markdown]
# Exercise 3

# %%
#x = 43
#x = X + 1
#print(x)
x = x + 1
#the error is the initialize big letter x
